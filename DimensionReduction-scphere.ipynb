# %%
# Import Libraries
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Bioinformatics Libraries
import scanpy as sc

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Scapy Settings
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.9.6 anndata==0.10.3 umap==0.5.5 numpy==1.26.2 scipy==1.11.4 pandas==2.1.4 scikit-learn==1.3.2 statsmodels==0.14.1 igraph==0.11.3 pynndescent==0.5.11

# %%
# Load the pbmc3k dataset
sc.datasets.pbmc3k()
adata = sc.read_10x_mtx(
    # the directory with the `.mtx` file
    './data/filtered_gene_bc_matrices/hg19/',
    # use gene symbols for the variable names (variables-axis index)
    var_names='gene_symbols',
    # write a cache file for faster subsequent reading
    cache=True,
)
# Out:
# ... reading from cache file cache/data-filtered_gene_bc_matrices-hg19-matrix.h5ad
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %% [markdown]
# ### scPhere
#
# it has its own data input and doesn't use adata from scanpy

# %%
x = read_mtx('data/filtered_gene_bc_matrices/hg19/matrix.mtx')
x = x.transpose().todense()

# %%
# For the cases there are no batch vectors, we can set n_batch=0, 
# and create an artificial batch vector (just for running scPhere, 
# the batch vector will not influence the results), e.g.,
batch = np.zeros(x.shape[0]) * -1

model = SCPHERE(n_gene=x.shape[1], n_batch=0,
                z_dim=2, latent_dist='vmf',
                observation_dist='nb', seed=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 6
#       1 # For the cases there are no batch vectors, we can set n_batch=0,
#       2 # and create an artificial batch vector (just for running scPhere,
#       3 # the batch vector will not influence the results), e.g.,
#       4 batch = np.zeros(x.shape[0]) * -1
# ----> 6 model = SCPHERE(n_gene=x.shape[1], n_batch=0,
#       7                 z_dim=2, latent_dist='vmf',
#       8                 observation_dist='nb', seed=0)
#
# File ~/miniconda3/envs/scsphere/lib/python3.9/site-packages/scPhere-0.1.0-py3.9.egg/scphere/model/vae.py:32, in SCPHERE.__init__(self, n_gene, n_batch, z_dim, encoder_layer, decoder_layer, activation, latent_dist, observation_dist, batch_invariant, seed)
#      30 self.n_input_feature = n_gene
#      31 # placeholder for gene expression data
# ---> 32 self.x = tf.compat.v1.placeholder(tf.float32,
#      33                                   shape=[None, n_gene], name='x')
#      35 self.z_dim, self.encoder_layer, self.decoder_layer, self.activation, \
#      36     self.latent_dist, self.observation_dist = \
#      37     z_dim, encoder_layer, decoder_layer, activation, \
#      38     latent_dist, observation_dist
#      40 if self.latent_dist is 'vmf':
#
# File ~/miniconda3/envs/scsphere/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:3271, in placeholder(dtype, shape, name)
#    3224 """Inserts a placeholder for a tensor that will be always fed.
#    3225
#    3226 **Important**: This tensor will produce an error if evaluated. Its value must
#    (...)
#    3268 @end_compatibility
#    3269 """
#    3270 if context.executing_eagerly():
# -> 3271   raise RuntimeError("tf.placeholder() is not compatible with "
#    3272                      "eager execution.")
#    3274 return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#
# RuntimeError: tf.placeholder() is not compatible with eager execution.

# %%
# Show those genes that yield the highest fraction of counts in each single cell, across all cells.
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
# Basic filtering
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# filtered out 19024 genes that are detected in less than 3 cells

# %%
# quality control
mito_genes = adata.var_names.str.startswith('MT-')
# for each cell compute fraction of counts in mito genes vs. all genes
# the `.A1` is only necessary as X is sparse (to transform to a dense array after summing)
adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1).A1

sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
                jitter=0.4, multi_panel=True)

adata = adata[adata.obs['n_genes'] < 2500, :]
adata = adata[adata.obs['percent_mito'] < 0.05, :]
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 2638 × 13714
#     obs: 'n_genes', 'percent_mito', 'n_counts'
#     var: 'gene_ids', 'n_cells'

# %%
# Normalize the data
sc.pp.normalize_total(adata, target_sum=1e4)

# Logarithmize the data
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
# Store the raw data
adata.raw = adata

# %%
# Identify highly variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)

# Filter the data
adata = adata[:, adata.var.highly_variable]

# Summarize the highly variable genes
print(adata.var.highly_variable.sum())
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# 1838

# %%
# Regress out effects of total counts per cell and the percentage of mitochondrial genes expressed.
sc.pp.regress_out(adata, ['n_counts', 'percent_mito'])
# Out:
# regressing out ['n_counts', 'percent_mito']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:02)

# %%
# Scale each gene to unit variance. Clip values exceeding standard deviation 10 to remove extreme outliers.
sc.pp.scale(adata, max_value=10)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts'
#     var: 'gene_ids', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg'

# %% [markdown]
# ## Dimension Reduction

# %% [markdown]
# ### scPhere

# %%
# Import Libraries
from scphere.util.util import read_mtx
from scphere.util.trainer import Trainer
from scphere.model.vae import SCPHERE

import logging
import tensorflow as tf
from scphere.distributions import VonMisesFisher

# %%
# Run PCA
sc.tl.pca(adata, svd_solver='arpack')

# Visualize the PCA results with coloring by 'n_genes'
sc.pl.pca(adata, color='n_genes', show=False)  # `show=False` to prevent immediate plot display

# Get current axis and figure
ax = plt.gca()
fig = plt.gcf()

# Find the color bar in the current figure
colorbar = ax.collections[0].colorbar

# Set the label for the color bar
colorbar.set_label('Number of Genes Detected')

# Display the plot
plt.show()
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:00)

# %%
# Plot the explained variance (PCA)
sc.pl.pca_variance_ratio(adata, log=True, n_pcs=30, show=True)  # `show=False` to prevent automatic display

# %%
# Write result file
adata.write('write/pbmc3k_pca.h5ad', compression='gzip')
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts'
#     var: 'gene_ids', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
